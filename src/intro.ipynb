# %%
using Images, ImageView, ImageFiltering

misty = load("misty.jpg")
#= You can find misty.jpg in the resources folder, 
make sure to put it in the same directory you run the code =#
# Out:
# 1600×1200 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.329,0.231,0.153)  …  RGB{N0f8}(0.235,0.29,0.341)
#  RGB{N0f8}(0.329,0.231,0.153)     RGB{N0f8}(0.224,0.278,0.329)
#  RGB{N0f8}(0.333,0.235,0.157)     RGB{N0f8}(0.204,0.259,0.31)
#  RGB{N0f8}(0.333,0.235,0.157)     RGB{N0f8}(0.184,0.239,0.29)
#  RGB{N0f8}(0.329,0.231,0.153)     RGB{N0f8}(0.173,0.227,0.278)
#  RGB{N0f8}(0.325,0.227,0.149)  …  RGB{N0f8}(0.173,0.227,0.278)
#  RGB{N0f8}(0.322,0.224,0.145)     RGB{N0f8}(0.176,0.231,0.282)
#  RGB{N0f8}(0.318,0.22,0.141)      RGB{N0f8}(0.18,0.235,0.286)
#  RGB{N0f8}(0.322,0.224,0.145)     RGB{N0f8}(0.161,0.216,0.267)
#  RGB{N0f8}(0.318,0.22,0.141)      RGB{N0f8}(0.153,0.208,0.259)
#  RGB{N0f8}(0.318,0.22,0.141)   …  RGB{N0f8}(0.145,0.2,0.251)
#  RGB{N0f8}(0.325,0.227,0.149)     RGB{N0f8}(0.149,0.204,0.255)
#  RGB{N0f8}(0.337,0.239,0.161)     RGB{N0f8}(0.137,0.192,0.243)
#  ⋮                             ⋱
#  RGB{N0f8}(0.082,0.078,0.059)     RGB{N0f8}(0.082,0.09,0.086)
#  RGB{N0f8}(0.078,0.075,0.055)     RGB{N0f8}(0.078,0.086,0.082)
#  RGB{N0f8}(0.075,0.071,0.051)  …  RGB{N0f8}(0.075,0.082,0.078)
#  RGB{N0f8}(0.067,0.063,0.043)     RGB{N0f8}(0.071,0.078,0.075)
#  RGB{N0f8}(0.09,0.086,0.067)      RGB{N0f8}(0.075,0.082,0.078)
#  RGB{N0f8}(0.082,0.078,0.059)     RGB{N0f8}(0.071,0.078,0.075)
#  RGB{N0f8}(0.075,0.071,0.051)     RGB{N0f8}(0.071,0.078,0.075)
#  RGB{N0f8}(0.071,0.067,0.047)  …  RGB{N0f8}(0.071,0.078,0.075)
#  RGB{N0f8}(0.067,0.063,0.043)     RGB{N0f8}(0.067,0.075,0.071)
#  RGB{N0f8}(0.071,0.067,0.047)     RGB{N0f8}(0.067,0.075,0.071)
#  RGB{N0f8}(0.078,0.075,0.055)     RGB{N0f8}(0.067,0.075,0.071)
#  RGB{N0f8}(0.082,0.078,0.059)     RGB{N0f8}(0.063,0.071,0.067)

# %%
cropped_misty = misty[500:800, 500:800] # we can crop the image by specifying a range of indices
# Out:
# 301×301 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.898,0.812,0.651)  …  RGB{N0f8}(0.471,0.498,0.537)
#  RGB{N0f8}(0.898,0.812,0.651)     RGB{N0f8}(0.471,0.498,0.537)
#  RGB{N0f8}(0.898,0.812,0.651)     RGB{N0f8}(0.467,0.494,0.533)
#  RGB{N0f8}(0.898,0.812,0.651)     RGB{N0f8}(0.467,0.494,0.533)
#  RGB{N0f8}(0.898,0.812,0.651)     RGB{N0f8}(0.467,0.494,0.533)
#  RGB{N0f8}(0.894,0.808,0.647)  …  RGB{N0f8}(0.455,0.482,0.522)
#  RGB{N0f8}(0.894,0.808,0.647)     RGB{N0f8}(0.416,0.443,0.482)
#  RGB{N0f8}(0.894,0.808,0.647)     RGB{N0f8}(0.376,0.404,0.443)
#  RGB{N0f8}(0.894,0.808,0.647)     RGB{N0f8}(0.345,0.373,0.412)
#  RGB{N0f8}(0.894,0.808,0.647)     RGB{N0f8}(0.31,0.337,0.376)
#  RGB{N0f8}(0.894,0.808,0.647)  …  RGB{N0f8}(0.275,0.302,0.341)
#  RGB{N0f8}(0.894,0.808,0.647)     RGB{N0f8}(0.267,0.294,0.333)
#  RGB{N0f8}(0.894,0.808,0.647)     RGB{N0f8}(0.275,0.302,0.341)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.361,0.263,0.176)     RGB{N0f8}(0.18,0.141,0.145)
#  RGB{N0f8}(0.337,0.239,0.153)  …  RGB{N0f8}(0.188,0.149,0.153)
#  RGB{N0f8}(0.314,0.216,0.129)     RGB{N0f8}(0.192,0.153,0.157)
#  RGB{N0f8}(0.333,0.235,0.149)     RGB{N0f8}(0.184,0.145,0.149)
#  RGB{N0f8}(0.384,0.286,0.2)       RGB{N0f8}(0.192,0.153,0.157)
#  RGB{N0f8}(0.439,0.341,0.255)     RGB{N0f8}(0.192,0.153,0.157)
#  RGB{N0f8}(0.408,0.31,0.224)   …  RGB{N0f8}(0.18,0.141,0.145)
#  RGB{N0f8}(0.294,0.196,0.11)      RGB{N0f8}(0.169,0.129,0.133)
#  RGB{N0f8}(0.306,0.208,0.122)     RGB{N0f8}(0.173,0.133,0.137)
#  RGB{N0f8}(0.333,0.235,0.149)     RGB{N0f8}(0.188,0.149,0.153)
#  RGB{N0f8}(0.282,0.184,0.098)     RGB{N0f8}(0.188,0.149,0.153)
#  RGB{N0f8}(0.325,0.227,0.141)  …  RGB{N0f8}(0.176,0.137,0.141)

# %%
reduced_misty = misty[1:5:end, 1:5:end] # this reduces the image size by only taking every 5th pixel.
# Out:
# 320×240 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.329,0.231,0.153)  …  RGB{N0f8}(0.18,0.227,0.282)
#  RGB{N0f8}(0.325,0.227,0.149)     RGB{N0f8}(0.188,0.235,0.29)
#  RGB{N0f8}(0.318,0.22,0.141)      RGB{N0f8}(0.2,0.247,0.302)
#  RGB{N0f8}(0.298,0.2,0.122)       RGB{N0f8}(0.204,0.251,0.306)
#  RGB{N0f8}(0.322,0.224,0.137)     RGB{N0f8}(0.208,0.255,0.302)
#  RGB{N0f8}(0.451,0.357,0.263)  …  RGB{N0f8}(0.204,0.251,0.298)
#  RGB{N0f8}(0.455,0.353,0.247)     RGB{N0f8}(0.196,0.243,0.29)
#  RGB{N0f8}(0.455,0.349,0.235)     RGB{N0f8}(0.196,0.243,0.29)
#  RGB{N0f8}(0.459,0.353,0.239)     RGB{N0f8}(0.184,0.231,0.278)
#  RGB{N0f8}(0.435,0.329,0.216)     RGB{N0f8}(0.169,0.216,0.263)
#  RGB{N0f8}(0.463,0.369,0.259)  …  RGB{N0f8}(0.176,0.224,0.271)
#  RGB{N0f8}(0.447,0.349,0.227)     RGB{N0f8}(0.192,0.239,0.286)
#  RGB{N0f8}(0.467,0.361,0.243)     RGB{N0f8}(0.184,0.231,0.278)
#  ⋮                             ⋱
#  RGB{N0f8}(0.098,0.082,0.078)     RGB{N0f8}(0.075,0.082,0.078)
#  RGB{N0f8}(0.094,0.09,0.082)      RGB{N0f8}(0.086,0.094,0.09)
#  RGB{N0f8}(0.055,0.055,0.047)  …  RGB{N0f8}(0.082,0.09,0.086)
#  RGB{N0f8}(0.059,0.063,0.043)     RGB{N0f8}(0.094,0.102,0.098)
#  RGB{N0f8}(0.118,0.122,0.102)     RGB{N0f8}(0.078,0.086,0.082)
#  RGB{N0f8}(0.098,0.102,0.082)     RGB{N0f8}(0.075,0.082,0.078)
#  RGB{N0f8}(0.071,0.067,0.047)     RGB{N0f8}(0.086,0.086,0.094)
#  RGB{N0f8}(0.067,0.063,0.043)  …  RGB{N0f8}(0.071,0.106,0.102)
#  RGB{N0f8}(0.106,0.102,0.082)     RGB{N0f8}(0.067,0.102,0.098)
#  RGB{N0f8}(0.075,0.071,0.051)     RGB{N0f8}(0.075,0.082,0.078)
#  RGB{N0f8}(0.075,0.071,0.051)     RGB{N0f8}(0.071,0.078,0.075)
#  RGB{N0f8}(0.071,0.067,0.047)     RGB{N0f8}(0.071,0.078,0.075)

# %%
red_square = zeros(RGB, 50, 50) #this creates a black 50x50 image
red_square[1:50, 1:50] .= RGB(1.0, 0.0, 0.0) #this makes every pixel value red since 1, 0, 0 is red in RGB
# Out:
# 50×50 view(::Array{RGB,2}, 1:50, 1:50) with eltype RGB:
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  ⋮                          ⋱
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)  …  RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)
#  RGB{Float64}(1.0,0.0,0.0)     RGB{Float64}(1.0,0.0,0.0)

# %%
#similarly, we can modify the pixels of misty
squaerd_misty = misty[50:100, 50:100] .= RGB(0.0, 0.5, 0.8)
imshow(misty) #we need this because for some reason jupyter only displays the modified pixels (disregard the output below)
# Out:
# Dict{String, Any} with 4 entries:
#   "gui"         => Dict{String, Any}("window"=>GtkWindowLeaf(name="", parent, w…
#   "roi"         => Dict{String, Any}("redraw"=>100: "map(clim-mapped image, inp…
#   "annotations" => 53: "input-14" = Dict{UInt64, Any}() Dict{UInt64, Any}
#   "clim"        => 52: "CLim" = CLim{RGB{Float64}}(RGB{Float64}(0.0,0.0,0.0), R…

# %%
invert(color::AbstractRGB) = RGB(1-color.r, 1-color.g, 1-color.b) 
# this function inverts r, g, b values of any image it is passed
inverted_misty = invert.(misty)
# Out:
# 1600×1200 Array{RGB{Float32},2} with eltype RGB{Float32}:
#  RGB{Float32}(0.670588,0.768627,0.847059)  …  RGB{Float32}(0.764706,0.709804,0.658823)
#  RGB{Float32}(0.670588,0.768627,0.847059)     RGB{Float32}(0.776471,0.721569,0.670588)
#  RGB{Float32}(0.666667,0.764706,0.843137)     RGB{Float32}(0.796078,0.741176,0.690196)
#  RGB{Float32}(0.666667,0.764706,0.843137)     RGB{Float32}(0.815686,0.760784,0.709804)
#  RGB{Float32}(0.670588,0.768627,0.847059)     RGB{Float32}(0.827451,0.772549,0.721569)
#  RGB{Float32}(0.67451,0.772549,0.85098)    …  RGB{Float32}(0.827451,0.772549,0.721569)
#  RGB{Float32}(0.678431,0.776471,0.854902)     RGB{Float32}(0.823529,0.768627,0.717647)
#  RGB{Float32}(0.682353,0.780392,0.858824)     RGB{Float32}(0.819608,0.764706,0.713725)
#  RGB{Float32}(0.678431,0.776471,0.854902)     RGB{Float32}(0.839216,0.784314,0.733333)
#  RGB{Float32}(0.682353,0.780392,0.858824)     RGB{Float32}(0.847059,0.792157,0.741176)
#  RGB{Float32}(0.682353,0.780392,0.858824)  …  RGB{Float32}(0.854902,0.8,0.74902)
#  RGB{Float32}(0.67451,0.772549,0.85098)       RGB{Float32}(0.85098,0.796078,0.745098)
#  RGB{Float32}(0.662745,0.760784,0.839216)     RGB{Float32}(0.862745,0.807843,0.756863)
#  ⋮                                         ⋱
#  RGB{Float32}(0.917647,0.921569,0.941176)     RGB{Float32}(0.917647,0.909804,0.913725)
#  RGB{Float32}(0.921569,0.92549,0.945098)      RGB{Float32}(0.921569,0.913725,0.917647)
#  RGB{Float32}(0.92549,0.929412,0.94902)    …  RGB{Float32}(0.92549,0.917647,0.921569)
#  RGB{Float32}(0.933333,0.937255,0.956863)     RGB{Float32}(0.929412,0.921569,0.92549)
#  RGB{Float32}(0.909804,0.913725,0.933333)     RGB{Float32}(0.92549,0.917647,0.921569)
#  RGB{Float32}(0.917647,0.921569,0.941176)     RGB{Float32}(0.929412,0.921569,0.92549)
#  RGB{Float32}(0.92549,0.929412,0.94902)       RGB{Float32}(0.929412,0.921569,0.92549)
#  RGB{Float32}(0.929412,0.933333,0.952941)  …  RGB{Float32}(0.929412,0.921569,0.92549)
#  RGB{Float32}(0.933333,0.937255,0.956863)     RGB{Float32}(0.933333,0.92549,0.929412)
#  RGB{Float32}(0.929412,0.933333,0.952941)     RGB{Float32}(0.933333,0.92549,0.929412)
#  RGB{Float32}(0.921569,0.92549,0.945098)      RGB{Float32}(0.933333,0.92549,0.929412)
#  RGB{Float32}(0.917647,0.921569,0.941176)     RGB{Float32}(0.937255,0.929412,0.933333)

# %%
gray_misty = Gray.(misty)
#we can also convert misty to grayscale like this
# Out:
# 1600×1200 Array{Gray{N0f8},2} with eltype Gray{N0f8}:
#  Gray{N0f8}(0.251)  Gray{N0f8}(0.251)  …  Gray{N0f8}(0.278)
#  Gray{N0f8}(0.251)  Gray{N0f8}(0.251)     Gray{N0f8}(0.267)
#  Gray{N0f8}(0.255)  Gray{N0f8}(0.255)     Gray{N0f8}(0.247)
#  Gray{N0f8}(0.255)  Gray{N0f8}(0.255)     Gray{N0f8}(0.227)
#  Gray{N0f8}(0.251)  Gray{N0f8}(0.251)     Gray{N0f8}(0.216)
#  Gray{N0f8}(0.247)  Gray{N0f8}(0.247)  …  Gray{N0f8}(0.216)
#  Gray{N0f8}(0.243)  Gray{N0f8}(0.243)     Gray{N0f8}(0.22)
#  Gray{N0f8}(0.239)  Gray{N0f8}(0.239)     Gray{N0f8}(0.224)
#  Gray{N0f8}(0.243)  Gray{N0f8}(0.243)     Gray{N0f8}(0.204)
#  Gray{N0f8}(0.239)  Gray{N0f8}(0.239)     Gray{N0f8}(0.196)
#  Gray{N0f8}(0.239)  Gray{N0f8}(0.239)  …  Gray{N0f8}(0.188)
#  Gray{N0f8}(0.247)  Gray{N0f8}(0.247)     Gray{N0f8}(0.192)
#  Gray{N0f8}(0.259)  Gray{N0f8}(0.259)     Gray{N0f8}(0.18)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.078)  Gray{N0f8}(0.075)     Gray{N0f8}(0.086)
#  Gray{N0f8}(0.075)  Gray{N0f8}(0.078)     Gray{N0f8}(0.082)
#  Gray{N0f8}(0.071)  Gray{N0f8}(0.082)  …  Gray{N0f8}(0.078)
#  Gray{N0f8}(0.063)  Gray{N0f8}(0.075)     Gray{N0f8}(0.075)
#  Gray{N0f8}(0.086)  Gray{N0f8}(0.086)     Gray{N0f8}(0.078)
#  Gray{N0f8}(0.078)  Gray{N0f8}(0.082)     Gray{N0f8}(0.075)
#  Gray{N0f8}(0.071)  Gray{N0f8}(0.078)     Gray{N0f8}(0.075)
#  Gray{N0f8}(0.067)  Gray{N0f8}(0.071)  …  Gray{N0f8}(0.075)
#  Gray{N0f8}(0.063)  Gray{N0f8}(0.071)     Gray{N0f8}(0.071)
#  Gray{N0f8}(0.067)  Gray{N0f8}(0.071)     Gray{N0f8}(0.071)
#  Gray{N0f8}(0.075)  Gray{N0f8}(0.071)     Gray{N0f8}(0.071)
#  Gray{N0f8}(0.078)  Gray{N0f8}(0.071)     Gray{N0f8}(0.067)

# %%
#this was i hope a basic introduction to image modification in julia. 
#please check other notebooks for more cool examples!
